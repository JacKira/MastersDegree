# %%
import pyodbc
import pandas as pd
import swifter
import seaborn as sns
import gc
import matplotlib.pyplot as plt
from tune_sklearn import TuneGridSearchCV, TuneSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.impute import SimpleImputer
import numpy as np
import evalml
import swifter
gc.collect()
# Out:
# 1189

# %%
def preproc_data(df):
    df.iloc[:, 2:-3] = df.iloc[:, 2:-3].fillna(0)
    df.online_purch_flg = df.online_purch_flg.map({False:0, True:1})
    df.sex = df.sex.fillna(0)
    df.age = df.age.fillna(35)
    return df

# %% [markdown]
# # Load Data

# %%
with pyodbc.connect('DRIVER={SQL SERVER};SERVER=SAS-CI-DB1-P') as conn:
    strq = 'SELECT DISTINCT phone\
                    , CommFlag\
                    , OrderFlag\
                    ,Order_Ago\
                    ,min_diff\
                   , max_diff\
                    ,avg_diff\
                    ,avg_check\
                    ,offline_Order_Ago\
                    ,min_offline_diff\
                    ,max_offline_diff\
                    ,avg_offline_diff\
                    ,avg_offline_check\
                    ,online_Order_Ago\
                    ,min_online_diff\
                    ,max_online_diff\
                    ,avg_online_diff\
                    ,avg_online_check\
                    ,sum_amount_3\
                    ,sum_amount_6\
                    ,sum_amount_9\
                    ,sum_amount_12\
                    ,sum_amount_15\
                    ,sum_amount_18\
                    ,cnt_amount_3\
                    ,cnt_amount_6\
                    ,cnt_amount_9\
                    ,cnt_amount_12\
                    ,cnt_amount_15\
                    ,cnt_amount_18\
                    ,sum_offline_amount_3\
                    ,sum_offline_amount_6\
                    ,sum_offline_amount_9\
                    ,sum_offline_amount_12\
                    ,sum_offline_amount_15\
                    ,sum_offline_amount_18\
                    ,cnt_offline_amount_3\
                    ,cnt_offline_amount_6\
                    ,cnt_offline_amount_9\
                    ,cnt_offline_amount_12\
                    ,cnt_offline_amount_15\
                    ,cnt_offline_amount_18\
                    ,sum_online_amount_3\
                    ,sum_online_amount_6\
                    ,sum_online_amount_9\
                    ,sum_online_amount_12\
                    ,sum_online_amount_15\
                    ,sum_online_amount_18\
                    ,cnt_online_amount_3\
                    ,cnt_online_amount_6\
                    ,cnt_online_amount_9\
                    ,cnt_online_amount_12\
                    ,cnt_online_amount_15\
                    ,cnt_online_amount_18\
                    ,online_purch_flg\
                    , age\
                    , LIFECYCLE_TYPE\
                    , sex \
                    FROM ##DataTrain\
                    WHERE cnt_amount_18 > 0'
    df = pd.read_sql(strq, conn)
# Out:
# pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy

# %%
df.dtypes
# Out:
# phone                     object
# CommFlag                   int64
# OrderFlag                  int64
# Order_Ago                  int64
# min_diff                 float64
# max_diff                 float64
# avg_diff                 float64
# avg_check                float64
# offline_Order_Ago        float64
# min_offline_diff         float64
# max_offline_diff         float64
# avg_offline_diff         float64
# avg_offline_check        float64
# online_Order_Ago         float64
# min_online_diff          float64
# max_online_diff          float64
# avg_online_diff          float64
# avg_online_check         float64
# sum_amount_3             float64
# sum_amount_6             float64
# sum_amount_9             float64
# sum_amount_12            float64
# sum_amount_15            float64
# sum_amount_18            float64
# cnt_amount_3               int64
# cnt_amount_6               int64
# cnt_amount_9               int64
# cnt_amount_12              int64
# cnt_amount_15              int64
# cnt_amount_18              int64
# sum_offline_amount_3     float64
# sum_offline_amount_6     float64
# sum_offline_amount_9     float64
# sum_offline_amount_12    float64
# sum_offline_amount_15    float64
# sum_offline_amount_18    float64
# cnt_offline_amount_3       int64
# cnt_offline_amount_6       int64
# cnt_offline_amount_9       int64
# cnt_offline_amount_12      int64
# cnt_offline_amount_15      int64
# cnt_offline_amount_18      int64
# sum_online_amount_3      float64
# sum_online_amount_6      float64
# sum_online_amount_9      float64
# sum_online_amount_12     float64
# sum_online_amount_15     float64
# sum_online_amount_18     float64
# cnt_online_amount_3        int64
# cnt_online_amount_6        int64
# cnt_online_amount_9        int64
# cnt_online_amount_12       int64
# cnt_online_amount_15       int64
# cnt_online_amount_18       int64
# online_purch_flg            bool
# age                      float64
# LIFECYCLE_TYPE             int64
# sex                      float64
# dtype: object

# %%
df.head()
# Out:
#          phone  CommFlag  OrderFlag  Order_Ago  min_diff  max_diff  avg_diff  \
# 0  70000020494         0          1          1       4.0     256.0      49.0
# 1  70000068068         0          0         10       NaN       NaN       NaN
# 2  70000069087         0          0          4       8.0      82.0      48.0
# 3  70000103922         0          0          1       1.0      98.0      27.0
# 4  70000146945         0          0          5       1.0     171.0      44.0
#
#    avg_check  offline_Order_Ago  min_offline_diff  ...  cnt_online_amount_3  \
# 0  3402.4222                1.0               4.0  ...                    8
# 1  1844.0000                NaN               NaN  ...                    0
# 2  9827.7000                4.0               8.0  ...                    0
# 3  3437.3096                3.0               1.0  ...                    1
# 4  4742.9785                5.0              36.0  ...                    0
#
#    cnt_online_amount_6  cnt_online_amount_9  cnt_online_amount_12  \
# 0                    9                   10                    10
# 1                    0                    0                     1
# 2                    0                    0                     1
# 3                    1                    1                     1
# 4                    0                    0                     0
#
#    cnt_online_amount_15  cnt_online_amount_18  online_purch_flg   age  \
# 0                    10                    13              True   NaN
# 1                     1                     1              True  47.0
# 2                     1                     1              True  35.0
# 3                     1                     1              True  33.0
# 4                     0                     9              True  21.0
#
#    LIFECYCLE_TYPE  sex
# 0               1  0.0
# 1               1  0.0
# 2               1  0.0
# 3               1  0.0
# 4               1  0.0
#
# [5 rows x 58 columns]

# %%
# med = df.age.median()
# df.age = df.age.swifter.apply(lambda x: x if (x > 16) and (x < 80) else med)
# df.age = df.age.fillna(med)
# df.sex = df.sex.fillna(round(df.sex.median()))
# df.Order_Ago = df.Order_Ago.fillna(36)

# %%
df.head()
# Out:
#          phone  CommFlag  OrderFlag  Order_Ago  min_diff  max_diff  avg_diff  \
# 0  70000020494         0          1          1       4.0     256.0      49.0
# 1  70000068068         0          0         10       NaN       NaN       NaN
# 2  70000069087         0          0          4       8.0      82.0      48.0
# 3  70000103922         0          0          1       1.0      98.0      27.0
# 4  70000146945         0          0          5       1.0     171.0      44.0
#
#    avg_check  offline_Order_Ago  min_offline_diff  ...  cnt_online_amount_3  \
# 0  3402.4222                1.0               4.0  ...                    8
# 1  1844.0000                NaN               NaN  ...                    0
# 2  9827.7000                4.0               8.0  ...                    0
# 3  3437.3096                3.0               1.0  ...                    1
# 4  4742.9785                5.0              36.0  ...                    0
#
#    cnt_online_amount_6  cnt_online_amount_9  cnt_online_amount_12  \
# 0                    9                   10                    10
# 1                    0                    0                     1
# 2                    0                    0                     1
# 3                    1                    1                     1
# 4                    0                    0                     0
#
#    cnt_online_amount_15  cnt_online_amount_18  online_purch_flg   age  \
# 0                    10                    13              True   NaN
# 1                     1                     1              True  47.0
# 2                     1                     1              True  35.0
# 3                     1                     1              True  33.0
# 4                     0                     9              True  21.0
#
#    LIFECYCLE_TYPE  sex
# 0               1  0.0
# 1               1  0.0
# 2               1  0.0
# 3               1  0.0
# 4               1  0.0
#
# [5 rows x 58 columns]

# %%
df.describe()
# Out:
#            CommFlag     OrderFlag     Order_Ago      min_diff      max_diff  \
# count  7.310018e+06  7.310018e+06  7.310018e+06  4.477311e+06  4.477311e+06
# mean   8.315423e-01  2.152717e-02  5.975048e+00  7.658973e+01  1.662730e+02
# std    3.742723e-01  1.451336e-01  4.321633e+00  1.025610e+02  1.025161e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  0.000000e+00  2.000000e+00  7.000000e+00  9.200000e+01
# 50%    1.000000e+00  0.000000e+00  5.000000e+00  3.100000e+01  1.530000e+02
# 75%    1.000000e+00  0.000000e+00  9.000000e+00  1.050000e+02  2.270000e+02
# max    1.000000e+00  1.000000e+00  1.800000e+01  5.480000e+02  5.480000e+02
#
#            avg_diff     avg_check  offline_Order_Ago  min_offline_diff  \
# count  4.477311e+06  7.310018e+06       6.695041e+06      4.115188e+06
# mean   1.143255e+02  2.710004e+03       6.131818e+00      7.745095e+01
# std    9.241288e+01  3.242469e+03       4.366500e+00      1.021542e+02
# min    1.000000e+00 -6.621741e+05       0.000000e+00      0.000000e+00
# 25%    5.100000e+01  1.127000e+03       2.000000e+00      7.000000e+00
# 50%    8.800000e+01  2.163225e+03       5.000000e+00      3.300000e+01
# 75%    1.500000e+02  3.569400e+03       1.000000e+01      1.070000e+02
# max    5.480000e+02  3.200000e+06       1.800000e+01      5.480000e+02
#
#        max_offline_diff  ...  sum_online_amount_18  cnt_online_amount_3  \
# count      4.115188e+06  ...          1.260434e+06         7.310018e+06
# mean       1.649482e+02  ...          5.908934e+03         7.093293e-02
# std        1.022047e+02  ...          4.382892e+04         5.781092e-01
# min        0.000000e+00  ...          2.000000e+00         0.000000e+00
# 25%        9.100000e+01  ...          2.073000e+03         0.000000e+00
# 50%        1.510000e+02  ...          3.704000e+03         0.000000e+00
# 75%        2.260000e+02  ...          6.465000e+03         0.000000e+00
# max        5.480000e+02  ...          2.986616e+07         6.390000e+02
#
#        cnt_online_amount_6  cnt_online_amount_9  cnt_online_amount_12  \
# count         7.310018e+06         7.310018e+06          7.310018e+06
# mean          1.101331e-01         1.685170e-01          2.419251e-01
# std           1.088324e+00         1.331768e+00          1.665111e+00
# min           0.000000e+00         0.000000e+00          0.000000e+00
# 25%           0.000000e+00         0.000000e+00          0.000000e+00
# 50%           0.000000e+00         0.000000e+00          0.000000e+00
# 75%           0.000000e+00         0.000000e+00          0.000000e+00
# max           1.345000e+03         1.743000e+03          2.075000e+03
#
#        cnt_online_amount_15  cnt_online_amount_18           age  \
# count          7.310018e+06          7.310018e+06  6.112303e+06
# mean           2.862332e-01          3.284810e-01  3.971211e+01
# std            1.973524e+00          2.054090e+00  1.230264e+01
# min            0.000000e+00          0.000000e+00  1.300000e+01
# 25%            0.000000e+00          0.000000e+00  3.100000e+01
# 50%            0.000000e+00          0.000000e+00  3.800000e+01
# 75%            0.000000e+00          0.000000e+00  4.800000e+01
# max            2.445000e+03          2.445000e+03  9.300000e+01
#
#        LIFECYCLE_TYPE           sex
# count    7.310018e+06  6.909262e+06
# mean     9.805717e-01  1.374258e-01
# std      1.380247e-01  3.442964e-01
# min      0.000000e+00  0.000000e+00
# 25%      1.000000e+00  0.000000e+00
# 50%      1.000000e+00  0.000000e+00
# 75%      1.000000e+00  0.000000e+00
# max      1.000000e+00  1.000000e+00
#
# [8 rows x 56 columns]

# %%
df.to_csv('DataSetUpLif.csv', index = False, sep = ';')

# %%
#print('Median age ', med)

# %%
del df

# %%
with pyodbc.connect('DRIVER={SQL SERVER};SERVER=SAS-CI-DB1-P') as conn:
    strq = 'SELECT * FROM ##Segs'
    segs = pd.read_sql(strq, conn)
display(segs.head())
print(segs.shape)
# Out:
# pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#    SEGMENT_N       MOBILE
# 0          7  79263601250
# 1          1  79262037864
# 2          1  79268635216
# 3          5  79139225553
# 4          6  79233000608
# (19280083, 2)

# %%
segs.to_csv('segments.csv', index = False)

# %% [markdown]
# # EDA

# %%
df = pd.read_csv('DataSetUpLif.zip', sep = ';', dtype={'phone':'str'})#.merge(pd.read_csv('segments.zip', dtype= {'MOBILE':'str', 'SEGMENT_N':'int'}), left_on='phone', right_on='MOBILE').query('SEGMENT_N > 3').drop(['SEGMENT_N'
                                                                       #                                                                                                     , 'MOBILE']
                                                                      #                                                                                                    , axis = 1)

# %%
display(df.head())
print(df.dtypes)
print(df.shape)
# Out:
#          phone  CommFlag  OrderFlag  Order_Ago  min_diff  max_diff  avg_diff  \
# 0  70000136255         1          0          5       3.0       9.0       6.0
# 1  70501081555         1          0          0       7.0     141.0      55.0
# 2  70501521555         1          0          4       1.0     402.0     201.0
# 3  70501655539         1          0          1      21.0     158.0      79.0
# 4  70501785797         1          0          1       6.0     138.0      45.0
#
#    avg_check  offline_Order_Ago  min_offline_diff  ...  cnt_online_amount_3  \
# 0  2637.8888                NaN               NaN  ...                    0
# 1  5817.5720                0.0               7.0  ...                    0
# 2  6115.9000                4.0               1.0  ...                    0
# 3  1544.5166                1.0              21.0  ...                    0
# 4  4680.2807                1.0               6.0  ...                    0
#
#    cnt_online_amount_6  cnt_online_amount_9  cnt_online_amount_12  \
# 0                    9                    9                     9
# 1                    0                    0                     0
# 2                    1                    1                     1
# 3                    0                    0                     0
# 4                    0                    0                     0
#
#    cnt_online_amount_15  cnt_online_amount_18  online_purch_flg   age  \
# 0                     9                     9              True  24.0
# 1                     0                     0             False  37.0
# 2                     1                     1              True  35.0
# 3                     0                     0             False  36.0
# 4                     0                     0             False  43.0
#
#    LIFECYCLE_TYPE  sex
# 0               0  0.0
# 1               1  0.0
# 2               1  0.0
# 3               1  0.0
# 4               1  0.0
#
# [5 rows x 58 columns]
# phone                     object
# CommFlag                   int64
# OrderFlag                  int64
# Order_Ago                  int64
# min_diff                 float64
# max_diff                 float64
# avg_diff                 float64
# avg_check                float64
# offline_Order_Ago        float64
# min_offline_diff         float64
# max_offline_diff         float64
# avg_offline_diff         float64
# avg_offline_check        float64
# online_Order_Ago         float64
# min_online_diff          float64
# max_online_diff          float64
# avg_online_diff          float64
# avg_online_check         float64
# sum_amount_3             float64
# sum_amount_6             float64
# sum_amount_9             float64
# sum_amount_12            float64
# sum_amount_15            float64
# sum_amount_18            float64
# cnt_amount_3               int64
# cnt_amount_6               int64
# cnt_amount_9               int64
# cnt_amount_12              int64
# cnt_amount_15              int64
# cnt_amount_18              int64
# sum_offline_amount_3     float64
# sum_offline_amount_6     float64
# sum_offline_amount_9     float64
# sum_offline_amount_12    float64
# sum_offline_amount_15    float64
# sum_offline_amount_18    float64
# cnt_offline_amount_3       int64
# cnt_offline_amount_6       int64
# cnt_offline_amount_9       int64
# cnt_offline_amount_12      int64
# cnt_offline_amount_15      int64
# cnt_offline_amount_18      int64
# sum_online_amount_3      float64
# sum_online_amount_6      float64
# sum_online_amount_9      float64
# sum_online_amount_12     float64
# sum_online_amount_15     float64
# sum_online_amount_18     float64
# cnt_online_amount_3        int64
# cnt_online_amount_6        int64
# cnt_online_amount_9        int64
# cnt_online_amount_12       int64
# cnt_online_amount_15       int64
# cnt_online_amount_18       int64
# online_purch_flg            bool
# age                      float64
# LIFECYCLE_TYPE             int64
# sex                      float64
# dtype: object
# (3147591, 58)

# %%
df = df.set_index('phone')
df.head()
# Out:
#              CommFlag  OrderFlag  Order_Ago  min_diff  max_diff  avg_diff  \
# phone
# 70000136255         1          0          5       3.0       9.0       6.0
# 70501081555         1          0          0       7.0     141.0      55.0
# 70501521555         1          0          4       1.0     402.0     201.0
# 70501655539         1          0          1      21.0     158.0      79.0
# 70501785797         1          0          1       6.0     138.0      45.0
#
#              avg_check  offline_Order_Ago  min_offline_diff  max_offline_diff  \
# phone
# 70000136255  2637.8888                NaN               NaN               NaN
# 70501081555  5817.5720                0.0               7.0             141.0
# 70501521555  6115.9000                4.0               1.0             402.0
# 70501655539  1544.5166                1.0              21.0             158.0
# 70501785797  4680.2807                1.0               6.0             138.0
#
#              ...  cnt_online_amount_3  cnt_online_amount_6  \
# phone        ...
# 70000136255  ...                    0                    9
# 70501081555  ...                    0                    0
# 70501521555  ...                    0                    1
# 70501655539  ...                    0                    0
# 70501785797  ...                    0                    0
#
#              cnt_online_amount_9  cnt_online_amount_12  cnt_online_amount_15  \
# phone
# 70000136255                    9                     9                     9
# 70501081555                    0                     0                     0
# 70501521555                    1                     1                     1
# 70501655539                    0                     0                     0
# 70501785797                    0                     0                     0
#
#              cnt_online_amount_18  online_purch_flg   age  LIFECYCLE_TYPE  sex
# phone
# 70000136255                     9              True  24.0               0  0.0
# 70501081555                     0             False  37.0               1  0.0
# 70501521555                     1              True  35.0               1  0.0
# 70501655539                     0             False  36.0               1  0.0
# 70501785797                     0             False  43.0               1  0.0
#
# [5 rows x 57 columns]

# %%
any(df.isna())
# Out:
# True

# %%
df = preproc_data(df)

# %%
colls = df.columns.tolist()
for coll in colls:
    if any(df[coll].isna()):
        print(coll)

# %%
df.iloc[:, 3:-3].head()
# Out:
#              min_diff  max_diff  avg_diff  avg_check  offline_Order_Ago  \
# phone
# 70000136255       3.0       9.0       6.0  2637.8888                0.0
# 70501081555       7.0     141.0      55.0  5817.5720                0.0
# 70501521555       1.0     402.0     201.0  6115.9000                4.0
# 70501655539      21.0     158.0      79.0  1544.5166                1.0
# 70501785797       6.0     138.0      45.0  4680.2807                1.0
#
#              min_offline_diff  max_offline_diff  avg_offline_diff  \
# phone
# 70000136255               0.0               0.0               0.0
# 70501081555               7.0             141.0              55.0
# 70501521555               1.0             402.0             201.0
# 70501655539              21.0             158.0              79.0
# 70501785797               6.0             138.0              45.0
#
#              avg_offline_check  online_Order_Ago  ...  sum_online_amount_12  \
# phone                                             ...
# 70000136255             0.0000               5.0  ...               23741.0
# 70501081555          5817.5720               0.0  ...                   0.0
# 70501521555          7244.8750               4.0  ...                1600.0
# 70501655539          1544.5166               0.0  ...                   0.0
# 70501785797          4680.2807               0.0  ...                   0.0
#
#              sum_online_amount_15  sum_online_amount_18  cnt_online_amount_3  \
# phone
# 70000136255               23741.0               23741.0                    0
# 70501081555                   0.0                   0.0                    0
# 70501521555                1600.0                1600.0                    0
# 70501655539                   0.0                   0.0                    0
# 70501785797                   0.0                   0.0                    0
#
#              cnt_online_amount_6  cnt_online_amount_9  cnt_online_amount_12  \
# phone
# 70000136255                    9                    9                     9
# 70501081555                    0                    0                     0
# 70501521555                    1                    1                     1
# 70501655539                    0                    0                     0
# 70501785797                    0                    0                     0
#
#              cnt_online_amount_15  cnt_online_amount_18  online_purch_flg
# phone
# 70000136255                     9                     9                 1
# 70501081555                     0                     0                 0
# 70501521555                     1                     1                 1
# 70501655539                     0                     0                 0
# 70501785797                     0                     0                 0
#
# [5 rows x 51 columns]

# %%
df.head()
# Out:
#              CommFlag  OrderFlag  Order_Ago  min_diff  max_diff  avg_diff  \
# phone
# 70000136255         1          0          5       3.0       9.0       6.0
# 70501081555         1          0          0       7.0     141.0      55.0
# 70501521555         1          0          4       1.0     402.0     201.0
# 70501655539         1          0          1      21.0     158.0      79.0
# 70501785797         1          0          1       6.0     138.0      45.0
#
#              avg_check  offline_Order_Ago  min_offline_diff  max_offline_diff  \
# phone
# 70000136255  2637.8888                0.0               0.0               0.0
# 70501081555  5817.5720                0.0               7.0             141.0
# 70501521555  6115.9000                4.0               1.0             402.0
# 70501655539  1544.5166                1.0              21.0             158.0
# 70501785797  4680.2807                1.0               6.0             138.0
#
#              ...  cnt_online_amount_3  cnt_online_amount_6  \
# phone        ...
# 70000136255  ...                    0                    9
# 70501081555  ...                    0                    0
# 70501521555  ...                    0                    1
# 70501655539  ...                    0                    0
# 70501785797  ...                    0                    0
#
#              cnt_online_amount_9  cnt_online_amount_12  cnt_online_amount_15  \
# phone
# 70000136255                    9                     9                     9
# 70501081555                    0                     0                     0
# 70501521555                    1                     1                     1
# 70501655539                    0                     0                     0
# 70501785797                    0                     0                     0
#
#              cnt_online_amount_18  online_purch_flg   age  LIFECYCLE_TYPE  sex
# phone
# 70000136255                     9                 1  24.0               0  0.0
# 70501081555                     0                 0  37.0               1  0.0
# 70501521555                     1                 1  35.0               1  0.0
# 70501655539                     0                 0  36.0               1  0.0
# 70501785797                     0                 0  43.0               1  0.0
#
# [5 rows x 57 columns]

# %%
m = df.iloc[:, 2:].mean()
sig = df.iloc[:, 2:].std()
df.iloc[:, 2:] = (df.iloc[:, 2:] - m) / (sig + 1e-12)

# %%
np.save('means.npy', m.values)
np.save('std.npy', sig.values)

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize = (15, 10))
sns.histplot(df.OrderFlag, label = 'Target', color = 'blue')
plt.legend()
plt.show()

fig, ax = plt.subplots(figsize = (15, 10))
sns.histplot(df.OrderFlag, label = 'Target%', color = 'blue', stat = 'probability')
ax.set_yticks(np.linspace(0, 1, 50))
ax.grid('both')
plt.legend()
plt.show()

sns.histplot(df.CommFlag, label = 'Treatment', color = 'red')
plt.legend()
plt.show()


fig, ax = plt.subplots(figsize = (15, 10))
sns.histplot(df.CommFlag, label = 'Treatment%', color = 'red', stat = 'probability')
ax.set_yticks(np.linspace(0, 1, 50))
ax.grid('both')
plt.legend()
plt.show()

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize = (50, 50))
corr_matrix = df.corr()

#Using heatmap to visualize the correlation matrix
sns.heatmap(corr_matrix, annot=True, ax = ax)
del corr_matrix

# %%
df.iloc[:, 2:].head()
# Out:
#              Order_Ago  min_diff  max_diff  avg_diff  avg_check  \
# phone
# 70000136255  -0.125533 -0.611077 -1.265538 -0.950191  -0.083766
# 70501081555  -1.427658 -0.590035 -0.595441 -0.677813   1.046191
# 70501521555  -0.385958 -0.621598  0.729525  0.133763   1.152208
# 70501655539  -1.167233 -0.516388 -0.509140 -0.544403  -0.472315
# 70501785797  -1.167233 -0.595295 -0.610670 -0.733400   0.642035
#
#              offline_Order_Ago  min_offline_diff  max_offline_diff  \
# phone
# 70000136255          -1.342213         -0.624741         -1.278591
# 70501081555          -1.342213         -0.587939         -0.569527
# 70501521555          -0.396243         -0.619483          0.742995
# 70501655539          -1.105721         -0.514334         -0.484037
# 70501785797          -1.105721         -0.593196         -0.584613
#
#              avg_offline_diff  avg_offline_check  ...  cnt_online_amount_3  \
# phone                                             ...
# 70000136255         -0.968908          -0.990069  ...            -0.088242
# 70501081555         -0.664678           1.062153  ...            -0.088242
# 70501521555          0.142913           1.565652  ...            -0.088242
# 70501655539         -0.531924          -0.445221  ...            -0.088242
# 70501785797         -0.719993           0.660959  ...            -0.088242
#
#              cnt_online_amount_6  cnt_online_amount_9  cnt_online_amount_12  \
# phone
# 70000136255            14.746600             8.695456              7.085026
# 70501081555            -0.104858            -0.087572             -0.091512
# 70501521555             1.545304             0.888320              0.705881
# 70501655539            -0.104858            -0.087572             -0.091512
# 70501785797            -0.104858            -0.087572             -0.091512
#
#              cnt_online_amount_15  cnt_online_amount_18  online_purch_flg  \
# phone
# 70000136255              5.938239              5.697424          3.308048
# 70501081555             -0.088777             -0.094621         -0.302293
# 70501521555              0.580892              0.548939          3.308048
# 70501655539             -0.088777             -0.094621         -0.302293
# 70501785797             -0.088777             -0.094621         -0.302293
#
#                   age  LIFECYCLE_TYPE       sex
# phone
# 70000136255 -1.517958       -3.211732 -0.343506
# 70501081555 -0.413218        0.311358 -0.343506
# 70501521555 -0.583178        0.311358 -0.343506
# 70501655539 -0.498198        0.311358 -0.343506
# 70501785797  0.096662        0.311358 -0.343506
#
# [5 rows x 55 columns]

# %%
y = df.iloc[:, 0:2]
p = round(y[y.CommFlag == 1].shape[0] / y.shape[0], 1) #0.5
Z = y.OrderFlag * (y.CommFlag - p) / (p * (1-p)) 
del y

gc.collect()
gc.enable()

features = df.iloc[:, 2:].columns.tolist()
X = df.iloc[:, 2:].replace(np.inf, 0).values

# %%
# for c in X.T:
#     if any(pd.isna(c)):
#         print('Ooops')

# %%
del df
gc.collect()
# Out:
# 0

# %%
p
# Out:
# 0.9

# %%
#X.head()

# %%
Z.describe()
# Out:
# count    3.147591e+06
# mean     9.459439e-03
# std      3.423001e-01
# min     -1.000000e+01
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.111111e+00
# dtype: float64

# %%
# imp_mean = SimpleImputer(missing_values=np.nan, strategy='median')
# scaler = StandardScaler()
# X = scaler.fit_transform(imp_mean.fit_transform(X))
# pd.isna(X).any()

# %%
# gc.collect()
# del X_test
# del X_train
# del y_test
# del y_train
# del automl

# %%
gc.collect()
# Out:
# 0

# %% [markdown]
# ## GridSearch

# %%
X_train,X_test,y_train,y_test=evalml.preprocessing.split_data(X, Z,problem_type='regression')

# %%
# for i, c in enumerate(X_train.T):
#     if pd.isna(c):
#         print(X_train.T[i])

# %%
del X
del Z

# %%
gc.collect()
gc.enable()

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [2, 4, 6, 10, 20],
    
    'min_samples_leaf': [1, 2, 3, 4, 6],
    'min_samples_split': [2, 4, 8],
    'n_estimators': [100]
}# Create a based model
rf = RandomForestRegressor(verbose = 1, n_jobs = -1)# Instantiate the grid search model
grid_search = TuneSearchCV(estimator = rf, param_distributions= param_grid, 
                           n_jobs = 4, verbose = 2)

# %%
grid_search.fit(X_train, y_train)

# %%
best = grid_search.best_estimator_

# %%
grid_search.best_params_

# %% [markdown]
# Best properties:<br>
# { <br>  'bootstrap': True, <br>
#     'max_depth': 6,<br>
#     'min_samples_leaf': 4,<br>
#     'min_samples_split': 4,<br>
#     'n_estimators': 100<br>
#  }

# %% [markdown]
# ## Train with best properties:<br>
# { <br>  'bootstrap': True, <br>
#     'max_depth': 6,<br>
#     'min_samples_leaf': 4,<br>
#     'min_samples_split': 4,<br>
#     'n_estimators': 100<br>
#  }

# %%
rf = RandomForestRegressor(bootstrap=True
                           , max_depth=6
                           ,min_samples_leaf=4
                           , min_samples_split= 4
                           , n_estimators= 100
                            , verbose = 1
                            , n_jobs = -1)# Instantiate the grid search model

# %%
rf.fit(X, Z)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 14.1min finished
# RandomForestRegressor(max_depth=6, min_samples_leaf=4, min_samples_split=4,
#                       n_jobs=-1, verbose=1)

# %%
est = rf.estimators_[5]

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
import matplotlib as mpl


fig = plt.figure(figsize=(50, 10))
plot_tree(rf.estimators_[0], 
          feature_names=features
          
          ,filled=True, impurity=True, 
          rounded=True)
plt.savefig('tree.png', dpi = 500)

# %%
import joblib
filename = 'best_RandomForest.sav'
joblib.dump(rf, filename)
# Out:
# ['best_RandomForest.sav']

# %%
for r in sorted(list(zip(features, rf.feature_importances_)), key = lambda x: -x[1]):
    print(f'{r[0]} : {r[1]:.2%}')
# Out:
# cnt_amount_3 : 12.90%
# cnt_offline_amount_3 : 8.60%
# cnt_amount_12 : 7.05%
# age : 4.56%
# sum_amount_3 : 3.45%
# avg_check : 2.89%
# avg_offline_check : 2.79%
# sum_offline_amount_3 : 2.70%
# cnt_offline_amount_6 : 2.69%
# cnt_amount_18 : 2.56%
# cnt_offline_amount_12 : 2.43%
# cnt_amount_6 : 2.41%
# online_Order_Ago : 2.35%
# avg_diff : 2.30%
# cnt_amount_15 : 2.13%
# sum_online_amount_18 : 2.08%
# sum_offline_amount_15 : 1.74%
# cnt_offline_amount_15 : 1.59%
# sum_amount_6 : 1.51%
# avg_online_check : 1.50%
# cnt_offline_amount_18 : 1.48%
# sum_online_amount_12 : 1.47%
# sum_offline_amount_9 : 1.44%
# sum_online_amount_6 : 1.43%
# max_diff : 1.40%
# sum_amount_15 : 1.31%
# cnt_offline_amount_9 : 1.23%
# cnt_amount_9 : 1.22%
# offline_Order_Ago : 1.17%
# sum_amount_9 : 1.15%
# sum_amount_12 : 1.13%
# sum_amount_18 : 1.11%
# sum_offline_amount_18 : 1.08%
# sum_online_amount_3 : 1.03%
# online_purch_flg : 1.03%
# sum_offline_amount_6 : 1.01%
# sum_online_amount_9 : 0.97%
# avg_offline_diff : 0.96%
# max_online_diff : 0.92%
# sum_offline_amount_12 : 0.90%
# max_offline_diff : 0.73%
# cnt_online_amount_15 : 0.70%
# cnt_online_amount_9 : 0.68%
# sum_online_amount_15 : 0.61%
# cnt_online_amount_18 : 0.58%
# cnt_online_amount_6 : 0.57%
# min_online_diff : 0.49%
# sex : 0.42%
# cnt_online_amount_3 : 0.38%
# avg_online_diff : 0.32%
# min_diff : 0.31%
# Order_Ago : 0.23%
# cnt_online_amount_12 : 0.20%
# min_offline_diff : 0.10%
# LIFECYCLE_TYPE : 0.00%

# %% [markdown]
# # Submition

# %%
from sklift.metrics import uplift_at_k
import joblib

# %%
filename = 'best_RandomForest.sav'
loaded_model = joblib.load(filename)

# %%
#Submission
subm = pd.read_csv('ControlSet.zip', sep = ';',dtype={'phone':'str', 'Order_Ago':'float64'})
subm = subm.set_index('phone')
subm.head()
# Out:
#              CommFlag  OrderFlag  Order_Ago  min_diff  max_diff  avg_diff  \
# phone
# 70000020494         0          1        1.0       4.0     256.0      49.0
# 70000068068         0          0       10.0       NaN       NaN       NaN
# 70000069087         0          0        4.0       8.0      82.0      48.0
# 70000103922         0          0        1.0       1.0      98.0      27.0
# 70000146945         0          0        5.0       1.0     171.0      44.0
#
#              avg_check  offline_Order_Ago  min_offline_diff  max_offline_diff  \
# phone
# 70000020494  3402.4222                1.0               4.0              23.0
# 70000068068  1844.0000                NaN               NaN               NaN
# 70000069087  9827.7000                4.0               8.0             109.0
# 70000103922  3437.3096                3.0               1.0              98.0
# 70000146945  4742.9785                5.0              36.0             171.0
#
#              ...  cnt_online_amount_3  cnt_online_amount_6  \
# phone        ...
# 70000020494  ...                    8                    9
# 70000068068  ...                    0                    0
# 70000069087  ...                    0                    0
# 70000103922  ...                    1                    1
# 70000146945  ...                    0                    0
#
#              cnt_online_amount_9  cnt_online_amount_12  cnt_online_amount_15  \
# phone
# 70000020494                   10                    10                    10
# 70000068068                    0                     1                     1
# 70000069087                    0                     1                     1
# 70000103922                    1                     1                     1
# 70000146945                    0                     0                     0
#
#              cnt_online_amount_18  online_purch_flg   age  LIFECYCLE_TYPE  sex
# phone
# 70000020494                    13              True   NaN               1  0.0
# 70000068068                     1              True  47.0               1  0.0
# 70000069087                     1              True  35.0               1  0.0
# 70000103922                     1              True  33.0               1  0.0
# 70000146945                     9              True  21.0               1  0.0
#
# [5 rows x 57 columns]

# %%
for r in sorted(list(zip(subm.iloc[:, 2:].columns.to_list(), loaded_model.feature_importances_)), key = lambda x: -x[1]):
    print(f'{r[0]} : {r[1]:.2%}')
# Out:
# cnt_amount_3 : 12.90%
# cnt_offline_amount_3 : 8.60%
# cnt_amount_12 : 7.05%
# age : 4.56%
# sum_amount_3 : 3.45%
# avg_check : 2.89%
# avg_offline_check : 2.79%
# sum_offline_amount_3 : 2.70%
# cnt_offline_amount_6 : 2.69%
# cnt_amount_18 : 2.56%
# cnt_offline_amount_12 : 2.43%
# cnt_amount_6 : 2.41%
# online_Order_Ago : 2.35%
# avg_diff : 2.30%
# cnt_amount_15 : 2.13%
# sum_online_amount_18 : 2.08%
# sum_offline_amount_15 : 1.74%
# cnt_offline_amount_15 : 1.59%
# sum_amount_6 : 1.51%
# avg_online_check : 1.50%
# cnt_offline_amount_18 : 1.48%
# sum_online_amount_12 : 1.47%
# sum_offline_amount_9 : 1.44%
# sum_online_amount_6 : 1.43%
# max_diff : 1.40%
# sum_amount_15 : 1.31%
# cnt_offline_amount_9 : 1.23%
# cnt_amount_9 : 1.22%
# offline_Order_Ago : 1.17%
# sum_amount_9 : 1.15%
# sum_amount_12 : 1.13%
# sum_amount_18 : 1.11%
# sum_offline_amount_18 : 1.08%
# sum_online_amount_3 : 1.03%
# online_purch_flg : 1.03%
# sum_offline_amount_6 : 1.01%
# sum_online_amount_9 : 0.97%
# avg_offline_diff : 0.96%
# max_online_diff : 0.92%
# sum_offline_amount_12 : 0.90%
# max_offline_diff : 0.73%
# cnt_online_amount_15 : 0.70%
# cnt_online_amount_9 : 0.68%
# sum_online_amount_15 : 0.61%
# cnt_online_amount_18 : 0.58%
# cnt_online_amount_6 : 0.57%
# min_online_diff : 0.49%
# sex : 0.42%
# cnt_online_amount_3 : 0.38%
# avg_online_diff : 0.32%
# min_diff : 0.31%
# Order_Ago : 0.23%
# cnt_online_amount_12 : 0.20%
# min_offline_diff : 0.10%
# LIFECYCLE_TYPE : 0.00%

# %%
subm = preproc_data(subm)

m = np.load('means.npy')
sig = np.load('std.npy')
subm.iloc[:, 2:] = (subm.iloc[:, 2:] - m) / (sig + 1e-12)

subm.head()
# Out:
#              CommFlag  OrderFlag  Order_Ago  min_diff  max_diff  avg_diff  \
# phone
# 70000020494         0          1  -1.167233 -0.605816 -0.011644 -0.711165
# 70000068068         0          0   1.176592 -0.626858 -1.311227 -0.983543
# 70000069087         0          0  -0.385958 -0.584774 -0.894954 -0.716724
# 70000103922         0          0  -1.167233 -0.621598 -0.813730 -0.833457
# 70000146945         0          0  -0.125533 -0.621598 -0.443146 -0.738959
#
#              avg_check  offline_Order_Ago  min_offline_diff  max_offline_diff  \
# phone
# 70000020494   0.187925          -1.105721         -0.603711         -1.162928
# 70000068068  -0.365889          -1.342213         -0.624741         -1.278591
# 70000069087   2.471262          -0.396243         -0.582681         -0.730449
# 70000103922   0.200322          -0.632736         -0.619483         -0.785766
# 70000146945   0.664315          -0.159751         -0.435473         -0.418662
#
#              ...  cnt_online_amount_3  cnt_online_amount_6  \
# phone        ...
# 70000020494  ...            22.910980            14.746600
# 70000068068  ...            -0.088242            -0.104858
# 70000069087  ...            -0.088242            -0.104858
# 70000103922  ...             2.786661             1.545304
# 70000146945  ...            -0.088242            -0.104858
#
#              cnt_online_amount_9  cnt_online_amount_12  cnt_online_amount_15  \
# phone
# 70000020494             9.671348              7.882419              6.607908
# 70000068068            -0.087572              0.705881              0.580892
# 70000069087            -0.087572              0.705881              0.580892
# 70000103922             0.888320              0.705881              0.580892
# 70000146945            -0.087572             -0.091512             -0.088777
#
#              cnt_online_amount_18  online_purch_flg       age  LIFECYCLE_TYPE  \
# phone
# 70000020494              8.271666          3.308048 -0.583178        0.311358
# 70000068068              0.548939          3.308048  0.436581        0.311358
# 70000069087              0.548939          3.308048 -0.583178        0.311358
# 70000103922              0.548939          3.308048 -0.753138        0.311358
# 70000146945              5.697424          3.308048 -1.772898        0.311358
#
#                   sex
# phone
# 70000020494 -0.343506
# 70000068068 -0.343506
# 70000069087 -0.343506
# 70000103922 -0.343506
# 70000146945 -0.343506
#
# [5 rows x 57 columns]

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize = (15, 10))
sns.histplot(subm.OrderFlag, label = 'Target', color = 'blue')
plt.legend()
plt.show()

fig, ax = plt.subplots(figsize = (15, 10))
sns.histplot(subm.OrderFlag, label = 'Target%', color = 'blue', stat = 'probability')
ax.set_yticks(np.linspace(0, 1, 50))
ax.grid('both')
plt.legend()
plt.show()

sns.histplot(subm.CommFlag, label = 'Treatment', color = 'red')
plt.legend()
plt.show()


fig, ax = plt.subplots(figsize = (15, 10))
sns.histplot(subm.CommFlag, label = 'Treatment%', color = 'red', stat = 'probability')
ax.set_yticks(np.linspace(0, 1, 50))
ax.grid('both')
plt.legend()
plt.show()

# %%
X_ = subm.iloc[:, 2:].values
X_val = subm.iloc[:, 2:]
Y_val = subm.iloc[:, [0, 1]]

# %%
del subm
gc.collect()
# Out:
# 17162

# %%
Y_val.head()
# Out:
#              CommFlag  OrderFlag
# phone
# 70000020494         0          1
# 70000068068         0          0
# 70000069087         0          0
# 70000103922         0          0
# 70000146945         0          0

# %%
Y_val_subm = Y_val[(Y_val['CommFlag'] == 1) & (Y_val['OrderFlag'] == 1)]
Y_val[(Y_val['CommFlag'] == 1) & (Y_val['OrderFlag'] == 1)].shape[0]
# Out:
# 135500

# %%
y_pred_1 = loaded_model.predict(X_)
y_pred_1
# Out:
# [Parallel(n_jobs=6)]: Using backend ThreadingBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=6)]: Done 100 out of 100 | elapsed:    6.5s finished
# array([0.07853987, 0.00633192, 0.02667493, ..., 0.00495966, 0.0080454 ,
#        0.00525897])

# %%
y_pred_1.shape
# Out:
# (7310018,)

# %%
sns.histplot(y_pred_1, bins = 50)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
X_val['UpLift'] = y_pred_1.tolist()
X_val['UpLift'].describe()
# Out:
# count    7.310018e+06
# mean     9.735291e-03
# std      2.444958e-02
# min     -2.449332e+00
# 25%      3.624369e-03
# 50%      7.462217e-03
# 75%      1.031229e-02
# max      9.215436e-01
# Name: UpLift, dtype: float64

# %%
X_val.head()
# Out:
#              Order_Ago  min_diff  max_diff  avg_diff  avg_check  \
# phone
# 70000020494  -1.167233 -0.605816 -0.011644 -0.711165   0.187925
# 70000068068   1.176592 -0.626858 -1.311227 -0.983543  -0.365889
# 70000069087  -0.385958 -0.584774 -0.894954 -0.716724   2.471262
# 70000103922  -1.167233 -0.621598 -0.813730 -0.833457   0.200322
# 70000146945  -0.125533 -0.621598 -0.443146 -0.738959   0.664315
#
#              offline_Order_Ago  min_offline_diff  max_offline_diff  \
# phone
# 70000020494          -1.105721         -0.603711         -1.162928
# 70000068068          -1.342213         -0.624741         -1.278591
# 70000069087          -0.396243         -0.582681         -0.730449
# 70000103922          -0.632736         -0.619483         -0.785766
# 70000146945          -0.159751         -0.435473         -0.418662
#
#              avg_offline_diff  avg_offline_check  ...  cnt_online_amount_6  \
# phone                                             ...
# 70000020494         -0.902531          -0.760801  ...            14.746600
# 70000068068         -0.968908          -0.990069  ...            -0.104858
# 70000069087         -0.637021           2.910229  ...            -0.104858
# 70000103922         -0.830622           0.243412  ...             1.545304
# 70000146945         -0.465546           1.440565  ...            -0.104858
#
#              cnt_online_amount_9  cnt_online_amount_12  cnt_online_amount_15  \
# phone
# 70000020494             9.671348              7.882419              6.607908
# 70000068068            -0.087572              0.705881              0.580892
# 70000069087            -0.087572              0.705881              0.580892
# 70000103922             0.888320              0.705881              0.580892
# 70000146945            -0.087572             -0.091512             -0.088777
#
#              cnt_online_amount_18  online_purch_flg       age  LIFECYCLE_TYPE  \
# phone
# 70000020494              8.271666          3.308048 -0.583178        0.311358
# 70000068068              0.548939          3.308048  0.436581        0.311358
# 70000069087              0.548939          3.308048 -0.583178        0.311358
# 70000103922              0.548939          3.308048 -0.753138        0.311358
# 70000146945              5.697424          3.308048 -1.772898        0.311358
#
#                   sex    UpLift
# phone
# 70000020494 -0.343506  0.078540
# 70000068068 -0.343506  0.006332
# 70000069087 -0.343506  0.026675
# 70000103922 -0.343506  0.076085
# 70000146945 -0.343506  0.010178
#
# [5 rows x 56 columns]

# %%
print(X_.shape)
print(X_val.shape)
# Out:
# (7310018, 55)
# (7310018, 56)

# %%
X_val_metric = X_val.merge(Y_val, on = 'phone')
print(X_val_metric.shape)
X_val_metric.head()
# Out:
# (7310018, 58)
#              Order_Ago  min_diff  max_diff  avg_diff  avg_check  \
# phone
# 70000020494  -1.167233 -0.605816 -0.011644 -0.711165   0.187925
# 70000068068   1.176592 -0.626858 -1.311227 -0.983543  -0.365889
# 70000069087  -0.385958 -0.584774 -0.894954 -0.716724   2.471262
# 70000103922  -1.167233 -0.621598 -0.813730 -0.833457   0.200322
# 70000146945  -0.125533 -0.621598 -0.443146 -0.738959   0.664315
#
#              offline_Order_Ago  min_offline_diff  max_offline_diff  \
# phone
# 70000020494          -1.105721         -0.603711         -1.162928
# 70000068068          -1.342213         -0.624741         -1.278591
# 70000069087          -0.396243         -0.582681         -0.730449
# 70000103922          -0.632736         -0.619483         -0.785766
# 70000146945          -0.159751         -0.435473         -0.418662
#
#              avg_offline_diff  avg_offline_check  ...  cnt_online_amount_12  \
# phone                                             ...
# 70000020494         -0.902531          -0.760801  ...              7.882419
# 70000068068         -0.968908          -0.990069  ...              0.705881
# 70000069087         -0.637021           2.910229  ...              0.705881
# 70000103922         -0.830622           0.243412  ...              0.705881
# 70000146945         -0.465546           1.440565  ...             -0.091512
#
#              cnt_online_amount_15  cnt_online_amount_18  online_purch_flg  \
# phone
# 70000020494              6.607908              8.271666          3.308048
# 70000068068              0.580892              0.548939          3.308048
# 70000069087              0.580892              0.548939          3.308048
# 70000103922              0.580892              0.548939          3.308048
# 70000146945             -0.088777              5.697424          3.308048
#
#                   age  LIFECYCLE_TYPE       sex    UpLift  CommFlag  OrderFlag
# phone
# 70000020494 -0.583178        0.311358 -0.343506  0.078540         0          1
# 70000068068  0.436581        0.311358 -0.343506  0.006332         0          0
# 70000069087 -0.583178        0.311358 -0.343506  0.026675         0          0
# 70000103922 -0.753138        0.311358 -0.343506  0.076085         0          0
# 70000146945 -1.772898        0.311358 -0.343506  0.010178         0          0
#
# [5 rows x 58 columns]

# %%
any(X_val_metric.OrderFlag.isna())
# Out:
# False

# %%
X_val_metric.CommFlag.values.min()
# Out:
# 0

# %%
from sklift.viz import plot_qini_curve, plot_uplift_curve, plot_uplift_by_percentile
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (15,10))
ax.set_title('Qini curves')

plot_qini_curve(y_true = X_val_metric.OrderFlag.values
                , uplift = X_val_metric.UpLift.values
                , treatment = X_val_metric.CommFlag.values
                , perfect = True, ax = ax)


fig, ax = plt.subplots(figsize = (15,10))
ax.set_title('UpLift curves')
plot_uplift_curve(y_true = X_val_metric.OrderFlag.values
                , uplift = X_val_metric.UpLift.values
                , treatment = X_val_metric.CommFlag.values
                , perfect = True, ax = ax)



plot_uplift_by_percentile(y_true = X_val_metric.OrderFlag.values
                , uplift = X_val_metric.UpLift.values 
                , treatment = X_val_metric.CommFlag.values, kind = 'bar')
# Out:
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# array([<AxesSubplot:title={'center':'Uplift by percentile\nweighted average uplift = 0.0045'}>,
#        <AxesSubplot:title={'center':'Response rate by percentile'}, xlabel='Percentile'>],
#       dtype=object)

# %%
h = 0.1
T = int(1 / h)
s = 0.01
cr = []
ac = []
part = []
X_val = X_val.sort_values('UpLift', ascending= False)
for i in range(0, T + 1):
    X_val_subm_i = X_val.iloc[0: round(X_val.shape[0] * s), :].merge(Y_val[Y_val['CommFlag'] == 1], on = 'phone', suffixes=('', '_y'))
    X_val_subm_i = X_val_subm_i.merge(Y_val_subm, how='left', on = 'phone', suffixes=('', '_y'))
    cr.append(X_val_subm_i[X_val_subm_i.OrderFlag == 1].shape[0] / X_val_subm_i.shape[0])
    ac.append(X_val_subm_i[X_val_subm_i.OrderFlag == 1].shape[0] / Y_val_subm.shape[0])
    part.append(s)
    del X_val_subm_i
    gc.collect()
    s += h

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(part, cr, label = 'CR')
plt.legend()
plt.xlabel('% of ranked clients')
plt.ylabel('Conversion')

plt.xlim(0, 1)
plt.show()

# %matplotlib inline
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(part, ac, label = 'Accuracy')

plt.xlim(0, 1)
plt.xlabel('% of ranked clients')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.DataFrame({'Part':part, 'CR':cr, 'ACC':ac})
# Out:
#     Part        CR       ACC
# 0   0.01  0.252541  0.124509
# 1   0.11  0.068389  0.356066
# 2   0.21  0.051114  0.496878
# 3   0.31  0.041512  0.598716
# 4   0.41  0.036428  0.689550
# 5   0.51  0.032334  0.756162
# 6   0.61  0.028579  0.802111
# 7   0.71  0.026703  0.865314
# 8   0.81  0.024733  0.910708
# 9   0.91  0.023282  0.958583
# 10  1.01  0.022291  1.000000

# %% [markdown]
# <p style = "font-color:blue;">
# Part	CR	ACC <br>
# 0.10	0.115568	0.317885<br>
# 0.15	0.098023	0.404434<br>
# 0.20	0.087061	0.478943<br>
# 0.25	0.079196	0.544595<br>
# 0.30	0.072784	0.600603<br>
# 0.35	0.067779	0.652520<br>
# 0.40	0.063647	0.700270<br>
# 0.45	0.060014	0.742842<br>
# 0.50	0.056950	0.783243<br>
# 0.55	0.054026	0.817332<br>
# 0.60	0.051604	0.851656<br>
# 0.65	0.049165	0.879014<br>
# 0.70	0.047004	0.905033<br>
# 0.75	0.044985	0.928019<br>
# 0.80	0.043039	0.947082<br>
# 0.85	0.041261	0.964702<br>
# 0.90	0.039611	0.980591<br>
# 0.95	0.037957	0.991854<br>
# 1.00	0.036355	1.000000<br>
# 1.05	0.036355	1.000000<br>
# </p>

# %%
Y_val[Y_val['CommFlag'] == 1].shape[0]
# Out:
# 3306567

# %%
 X_val.sort_values('UpLift', ascending= False).iloc[0: round(X_val.shape[0] * s), :].merge(Y_val[Y_val['CommFlag'] == 1], on = 'phone', suffixes=('', '_y')).shape
# Out:
# (506975, 43)

# %%
X_val_subm.head()
# Out:
#              Order_Ago  min_diff  max_diff  avg_diff  avg_check  \
# phone
# 79000000911        2.0       0.0       0.0       0.0  5471.0000
# 79000001507        3.0       0.0       0.0       0.0   893.0000
# 79000002803       12.0      43.0      43.0      43.0  4073.0833
# 79000002888        4.0       0.0       0.0       0.0  5233.0000
# 79000003036        6.0     137.0     137.0     137.0  2909.0000
#
#              avg_mass_check  Mean_Item_Cost  sum_amount_18  cnt_amount_18  \
# phone
# 79000000911         5471.00     5471.000000        5471.00              1
# 79000001507          893.00      893.000000         893.00              1
# 79000002803         4069.75     6109.625000       12219.25              3
# 79000002888         5233.00     2616.500000        5233.00              1
# 79000003036         2905.50      646.444444        5818.00              2
#
#              Mass_amount_18  ...  Lux_Parfume_Amount_9  Lux_Parfume_Amount_12  \
# phone                        ...
# 79000000911         5471.00  ...                   0.0                    0.0
# 79000001507          893.00  ...                   0.0                    0.0
# 79000002803        12209.25  ...                   0.0                    0.0
# 79000002888         5233.00  ...                   0.0                    0.0
# 79000003036         5811.00  ...                   0.0                    0.0
#
#              Lux_Parfume_Amount_15   age  LIFECYCLE_TYPE  sex  CommFlag_x  \
# phone
# 79000000911                    0.0   NaN               0  1.0         NaN
# 79000001507                    0.0  41.0               1  0.0         NaN
# 79000002803                    0.0  30.0               1  1.0         NaN
# 79000002888                    0.0   NaN               1  0.0         NaN
# 79000003036                    0.0  39.0               1  1.0         NaN
#
#              OrderFlag_x  CommFlag_y  OrderFlag_y
# phone
# 79000000911          NaN         NaN          NaN
# 79000001507          NaN         NaN          NaN
# 79000002803          NaN         NaN          NaN
# 79000002888          NaN         NaN          NaN
# 79000003036          NaN         NaN          NaN
#
# [5 rows x 44 columns]

# %%
h = 0.1
s = 0.1
cr = []
ac = []
part = []
for i in range(0, 10):
    X_val_subm_i = X_val.sort_values('UpLift', ascending= False).iloc[0: round(X_val.shape[0] * s), :]
    X_val_subm_i = X_val_subm_i.merge(Y_val_subm, how='left', on = 'phone', suffixes=('', '_y'))
    cr.append(X_val_subm_i[X_val_subm_i.OrderFlag == 1].shape[0] / X_val_subm_i.shape[0])
    ac.append(X_val_subm_i[X_val_subm_i.OrderFlag == 1].shape[0] / Y_val_subm.shape[0])
    part.append(s)
    del X_val_subm_i
    gc.collect()
    s += h
    
    
# %matplotlib inline
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(part, cr, label = 'CR')
plt.legend()
plt.xlabel('% of ranked clients')
plt.ylabel('Conversion')

plt.xlim(0, 1)
plt.show()

# %matplotlib inline
fig, ax = plt.subplots(figsize = (15, 10))
plt.plot(part, ac, label = 'Accuracy')

plt.xlim(0, 1)
plt.xlabel('% of ranked clients')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
pd.DataFrame({'CR':cr, 'Part':part})
# Out:
#          CR  Part
# 0  0.136361   0.1
# 1  0.097872   0.2
# 2  0.078931   0.3
# 3  0.068516   0.4
# 4  0.060734   0.5
# 5  0.054218   0.6
# 6  0.048734   0.7
# 7  0.043914   0.8
# 8  0.039896   0.9
# 9  0.036616   1.0

# %%
del subm
del X_val
del Y_val
del X_val_subm
del Y_val_subm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\fejzullin\Documents\AdHocRepo\UpLift\Second Step\Jupyter\EDA\EDA.ipynb Cell 64' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fejzullin/Documents/AdHocRepo/UpLift/Second%20Step/Jupyter/EDA/EDA.ipynb#ch0000071?line=0'>1</a> del subm
#       <a href='vscode-notebook-cell:/c%3A/Users/fejzullin/Documents/AdHocRepo/UpLift/Second%20Step/Jupyter/EDA/EDA.ipynb#ch0000071?line=1'>2</a> del X_val
#       <a href='vscode-notebook-cell:/c%3A/Users/fejzullin/Documents/AdHocRepo/UpLift/Second%20Step/Jupyter/EDA/EDA.ipynb#ch0000071?line=2'>3</a> del Y_val
#
# NameError: name 'subm' is not defined

# %%
gc.collect()
# Out:
# 8337

# %% [markdown]
# # Load Submission

# %%
with pyodbc.connect('DRIVER={SQL SERVER};SERVER=SAS-CI-DB1-P;') as conn:
    strq = 'SELECT DISTINCT phone\
                    , CommFlag\
                    , OrderFlag\
                    ,Order_Ago\
                    ,min_diff\
                   , max_diff\
                    ,avg_diff\
                    ,avg_check\
                    ,offline_Order_Ago\
                    ,min_offline_diff\
                    ,max_offline_diff\
                    ,avg_offline_diff\
                    ,avg_offline_check\
                    ,online_Order_Ago\
                    ,min_online_diff\
                    ,max_online_diff\
                    ,avg_online_diff\
                    ,avg_online_check\
                    ,sum_amount_3\
                    ,sum_amount_6\
                    ,sum_amount_9\
                    ,sum_amount_12\
                    ,sum_amount_15\
                    ,sum_amount_18\
                    ,cnt_amount_3\
                    ,cnt_amount_6\
                    ,cnt_amount_9\
                    ,cnt_amount_12\
                    ,cnt_amount_15\
                    ,cnt_amount_18\
                    ,sum_offline_amount_3\
                    ,sum_offline_amount_6\
                    ,sum_offline_amount_9\
                    ,sum_offline_amount_12\
                    ,sum_offline_amount_15\
                    ,sum_offline_amount_18\
                    ,cnt_offline_amount_3\
                    ,cnt_offline_amount_6\
                    ,cnt_offline_amount_9\
                    ,cnt_offline_amount_12\
                    ,cnt_offline_amount_15\
                    ,cnt_offline_amount_18\
                    ,sum_online_amount_3\
                    ,sum_online_amount_6\
                    ,sum_online_amount_9\
                    ,sum_online_amount_12\
                    ,sum_online_amount_15\
                    ,sum_online_amount_18\
                    ,cnt_online_amount_3\
                    ,cnt_online_amount_6\
                    ,cnt_online_amount_9\
                    ,cnt_online_amount_12\
                    ,cnt_online_amount_15\
                    ,cnt_online_amount_18\
                    ,online_purch_flg\
                    , age\
                    , LIFECYCLE_TYPE\
                    , sex \
                    FROM ##DataSubm\
                    WHERE cnt_amount_18 > 0'
    df = pd.read_sql(strq, conn)
# Out:
# pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy

# %%
df.head()
# Out:
#          phone  CommFlag  OrderFlag  Order_Ago  min_diff  max_diff  avg_diff  \
# 0  70000136255         1          0          5       3.0       9.0       6.0
# 1  70501081555         1          0          0       7.0     141.0      55.0
# 2  70501521555         1          0          4       1.0     402.0     201.0
# 3  70501655539         1          0          1      21.0     158.0      79.0
# 4  70501785797         1          0          1       6.0     138.0      45.0
#
#    avg_check  offline_Order_Ago  min_offline_diff  ...  cnt_online_amount_3  \
# 0  2637.8888                NaN               NaN  ...                    0
# 1  5817.5720                0.0               7.0  ...                    0
# 2  6115.9000                4.0               1.0  ...                    0
# 3  1544.5166                1.0              21.0  ...                    0
# 4  4680.2807                1.0               6.0  ...                    0
#
#    cnt_online_amount_6  cnt_online_amount_9  cnt_online_amount_12  \
# 0                    9                    9                     9
# 1                    0                    0                     0
# 2                    1                    1                     1
# 3                    0                    0                     0
# 4                    0                    0                     0
#
#    cnt_online_amount_15  cnt_online_amount_18  online_purch_flg   age  \
# 0                     9                     9              True  24.0
# 1                     0                     0             False  37.0
# 2                     1                     1              True  35.0
# 3                     0                     0             False  36.0
# 4                     0                     0             False  43.0
#
#    LIFECYCLE_TYPE  sex
# 0               0  0.0
# 1               1  0.0
# 2               1  0.0
# 3               1  0.0
# 4               1  0.0
#
# [5 rows x 58 columns]

# %%
df[df.Order_Ago.isna()]
# Out:
# Empty DataFrame
# Columns: [phone, CommFlag, OrderFlag, Order_Ago, min_diff, max_diff, avg_diff, avg_check, offline_Order_Ago, min_offline_diff, max_offline_diff, avg_offline_diff, avg_offline_check, online_Order_Ago, min_online_diff, max_online_diff, avg_online_diff, avg_online_check, sum_amount_3, sum_amount_6, sum_amount_9, sum_amount_12, sum_amount_15, sum_amount_18, cnt_amount_3, cnt_amount_6, cnt_amount_9, cnt_amount_12, cnt_amount_15, cnt_amount_18, sum_offline_amount_3, sum_offline_amount_6, sum_offline_amount_9, sum_offline_amount_12, sum_offline_amount_15, sum_offline_amount_18, cnt_offline_amount_3, cnt_offline_amount_6, cnt_offline_amount_9, cnt_offline_amount_12, cnt_offline_amount_15, cnt_offline_amount_18, sum_online_amount_3, sum_online_amount_6, sum_online_amount_9, sum_online_amount_12, sum_online_amount_15, sum_online_amount_18, cnt_online_amount_3, cnt_online_amount_6, cnt_online_amount_9, cnt_online_amount_12, cnt_online_amount_15, cnt_online_amount_18, online_purch_flg, age, LIFECYCLE_TYPE, sex]
# Index: []
#
# [0 rows x 58 columns]

# %%
df.to_csv('ControlSet.csv', index = False, sep = ';')

# %%
del df

# %%
gc.collect()
# Out:
# 0
