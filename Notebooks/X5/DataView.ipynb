# %%
import pandas as pd
import pyodbc
import numpy as np

# %% [markdown]
# # Данные покупателей

# %%
with pyodbc.connect('DRIVER={SQL SERVER};SERVER=DESKTOP-CCQDQVO') as conn:
    strq = 'SELECT * FROM X5.dbo.X5_DATA_SET'
    df_clients = pd.read_sql(strq, conn)

display(df_clients.head())
display(df_clients.describe())
print(df_clients.shape)
# Out:
#     client_id      MeanChk  MeanItemCost  Chks  last_chk_ago  \
# 0  fa4ef062c1   280.924000     53.785247    20            14
# 1  e2652509f4   300.000000     73.065146    30             4
# 2  7cef4b564e   192.403846     71.013718    13             4
# 3  1292a2aeae   506.583571     90.585577    14             2
# 4  bbadac1567  1172.320000     72.489040     3            20
#
#    Mean_TOP_1_BRAND  Mean_TOP_2_BRAND  Mean_TOP_3_BRAND  Mean_TOP_4_BRAND  \
# 0          0.335444          0.026667          0.032522          0.145817
# 1          0.096885          0.085866          0.040000          0.102493
# 2          0.211538          0.064103          0.000000          0.000000
# 3          0.079762          0.000000          0.048810          0.081548
# 4          0.082935          0.084211          0.000000          0.114514
#
#    Mean_TOP_5_BRAND  ...  Mean_TOP_2_LVL  Mean_TOP_3_LVL  Mean_TOP_4_LVL  \
# 0          0.026136  ...        0.307511        0.004545             0.0
# ...

# %%
df_clients.to_csv('D:\\Documents\\GitHub\\MastersDegree\\Datasets\\X5\\data\X5_clients_data.csv', index = False)

# %%
df_clients = df_clients.merge(pd.read_csv('D:\\Documents\\GitHub\\MastersDegree\\Datasets\\X5\\data\\uplift_train.csv'), on = 'client_id')

# %%
df_clients.to_csv('D:\\Documents\\GitHub\\MastersDegree\\Datasets\\X5\\data\X5_clients_data_train.csv', index = False)

# %%
display(df_clients.head())
display(df_clients.describe())
print(df_clients.shape)
# Out:
#     client_id      MeanChk  MeanItemCost  Chks  last_chk_ago  \
# 0  e2652509f4   300.000000     73.065146    30             4
# 1  7cef4b564e   192.403846     71.013718    13             4
# 2  1292a2aeae   506.583571     90.585577    14             2
# 3  bbadac1567  1172.320000     72.489040     3            20
# 4  09c55f2885   137.880000     59.411250    40             0
#
#    Mean_TOP_1_BRAND  Mean_TOP_2_BRAND  Mean_TOP_3_BRAND  Mean_TOP_4_BRAND  \
# 0          0.096885          0.085866          0.040000          0.102493
# 1          0.211538          0.064103          0.000000          0.000000
# 2          0.079762          0.000000          0.048810          0.081548
# 3          0.082935          0.084211          0.000000          0.114514
# 4          0.416667          0.023750          0.112917          0.000000
#
#    Mean_TOP_5_BRAND  ...  Mean_TOP_4_LVL  Mean_alc  Mean_CTM  Mean_netto  \
# 0          0.131647  ...             0.0  0.000000  0.349934    2.714800
# ...

# %% [markdown]
# # Данные для обучения

# %%
df_train = pd.read_csv('D:\\Documents\\GitHub\\MastersDegree\\Datasets\\X5\\data\\uplift_train.csv')
display(df_train.head())
display(df_train.tail())
display(df_train.describe())
print(df_train.shape)
# Out:
#     client_id  treatment_flg  target
# 0  000012768d              0       1
# 1  000036f903              1       1
# 2  00010925a5              1       1
# 3  0001f552b0              1       1
# 4  00020e7b18              1       1
#          client_id  treatment_flg  target
# 200034  fffe0abb97              0       0
# 200035  fffe0ed719              0       1
# 200036  fffea1204c              0       1
# 200037  fffeca6d22              1       0
# 200038  fffff6ce77              0       1
#        treatment_flg         target
# count  200039.000000  200039.000000
# mean        0.499808       0.619889
# std         0.500001       0.485415
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       1.000000
# 75%         1.000000       1.000000
# max         1.000000       1.000000
# (200039, 3)
